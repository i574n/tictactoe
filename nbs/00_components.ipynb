# %%
# default_exp components

# %%
import sys
sys.path.append('..')
import lib_py.ipython_magic as ipython_magic

# %% [markdown]
# # ???

# %%
# %%spiral
#
#
# open lib_spi.util
# open lib_spi.console_fsx
#
#
# inl imports () =
#     $"#r \"nuget: Feliz.JSX.Solid, 1.0.0-beta-001\""
#     $"open System"
#     $"open Fable.Core"
#     $"open Fable.Core.JsInterop"
#     $"open Feliz.JSX.Solid"
#
# inl tests () =
#     inl a = 1i32
#     inl b = 1i32
#     test (a = b)
#
#
# // fsx_ts
#
# nominal js_function_ = $"JS.Function"
# inl __obj obj : _obj = $"!obj"
#
# inl import name module =
#     inl name : string = name
#     inl module : string = module
#     $"import !name !module" : js_function_
#
#
# // solid
#
# inl createComponent_ () = import "createComponent" "solid-js"
# inl createEffect_ () = import "createEffect" "solid-js"
# inl createSignal_ () = import "createSignal" "solid-js"
# inl mergeProps_ ()  = import "mergeProps" "solid-js"
# inl on_ ()  = import "on" "solid-js"
# inl useStoreon_ () = import "useStoreon" "@storeon/solidjs"
#
# nominal element_ = $"JSX.Element"
# nominal prop_ = $"JSX.Prop"
# nominal prop_list_ = $"JSX.Prop list"
#
# inl create_obj obj =
#     inl obj : a i32 prop_ = obj
#     $"createObj !obj" : _obj
#
# inl new_jsx_prop k v =
#     $"JSX.Prop (!k, !v)"
#
# let jsx_prop k v : option prop_ =
#     v |> optionm.map (fun v => new_jsx_prop k v)
#
# inl __element el : element_ = $"!el"
#
# // inl create_jsx cmp props =
# //     inl props : a i32 prop_ = props
# //     inl result : element_ = $"JSX.create !cmp (!props |> unbox<JSX.Prop list>)"
# //     result
#
# inl str str : element_ =
#     inl str : string = str
#     $"Html.fragment [ !str |> unbox<JSX.Element> ]"
#
#
# // icons
#
# inl biRegularDownArrow_ () : js_function_ = import "BiRegularDownArrow" "solid-icons/bi"
# inl biRegularLinkExternal_ () : js_function_ = import "BiRegularLinkExternal" "solid-icons/bi"
# inl biRegularRefresh_ () : js_function_ = import "BiRegularRefresh" "solid-icons/bi"
# inl biRegularUpArrow_ () : js_function_ = import "BiRegularUpArrow" "solid-icons/bi"
# inl biRegularUndo_ () : js_function_ = import "BiRegularUndo" "solid-icons/bi"
#
#
# // ui
#
# type props__ =
#     {
#         ariaLabel : option string
#         as' : option js_function_
#         backgroundColor : option string
#         border : option string
#         bottom : option string
#         color : option string
#         checked : option bool
#         children : option (() -> element_)
#         colorScheme : option string
#         compact : option bool
#         direction : option string
#         display : option string
#         external : option bool
#         flex : option i32
#         flexDirection : option string
#         fontSize : option string
#         height : option string
#         href : option string
#         icon : option element_
#         id : option string
#         justifyContent : option string
#         left : option string
#         leftIcon : option _obj
#         lineHeight : option string
#         margin : option string
#         marginBottom : option string
#         maxHeight : option string
#         onChange : option (_obj -> ())
#         onClick : option (() -> ())
#         outline : option string
#         overflowY : option string
#         padding : option string
#         paddingTop : option string
#         position : option string
#         right : option string
#         size : option string
#         spacing : option string
#         status : option bool
#         striped : option string
#         thickness : option string
#         title : option element_
#         top : option string
#         width : option string
#         zIndex : option i32
#     }
#
# nominal props_heap = heap props__
#
# inl new_props props =
#     inl props : props__ = props
#     props_heap (heap props)
#
# let empty_props () : props__ =
#     {
#         ariaLabel = None
#         as' = None
#         backgroundColor = None
#         border = None
#         bottom = None
#         color = None
#         checked = None
#         children = None
#         colorScheme = None
#         compact = None
#         direction = None
#         display = None
#         external = None
#         flex = None
#         flexDirection = None
#         fontSize = None
#         height = None
#         href = None
#         icon = None
#         id = None
#         status = None
#         justifyContent = None
#         left = None
#         leftIcon = None
#         lineHeight = None
#         margin = None
#         marginBottom = None
#         maxHeight = None
#         onChange = None
#         onClick = None
#         outline = None
#         overflowY = None
#         padding = None
#         paddingTop = None
#         position = None
#         right = None
#         size = None
#         spacing = None
#         striped = None
#         thickness = None
#         title = None
#         top = None
#         width = None
#         zIndex = None
#     }
#
# let create_obj_props props =
#     inl props : a i32 (string * _obj) = props
#
#     inl empty_props' = empty_props ()
#
#     inl v' v = Some $"!v |> unbox"
#
#     props
#     |> am.fold (fun acc (k, v) =>
#         inl acc : props__ = acc
#         if $"!v = JS.undefined" then
#             acc
#         else
#             match k with
#             | "aria-label" => { acc with ariaLabel = v' v }
#             | "as" => { acc with as' = v' v }
#             | "backgroundColor" => { acc with backgroundColor = v' v }
#             | "border" => { acc with border = v' v }
#             | "bottom" => { acc with bottom = v' v }
#             | "color" => { acc with color = v' v }
#             | "checked" => { acc with checked = v' v }
#             | "children" => { acc with children = v' v }
#             | "colorScheme" => { acc with colorScheme = v' v }
#             | "compact" => { acc with compact = v' v }
#             | "display" => { acc with display = v' v }
#             | "direction" => { acc with direction = v' v }
#             | "external" => { acc with external = v' v }
#             | "flex" => { acc with flex = v' v }
#             | "flexDirection" => { acc with flexDirection = v' v }
#             | "fontSize" => { acc with fontSize = v' v }
#             | "height" => { acc with height = v' v }
#             | "href" => { acc with href = v' v }
#             | "icon" => { acc with icon = v' v }
#             | "id" => { acc with id = v' v }
#             | "justifyContent" => { acc with justifyContent = v' v }
#             | "left" => { acc with left = v' v }
#             | "leftIcon" => { acc with leftIcon = v' v }
#             | "lineHeight" => { acc with lineHeight = v' v }
#             | "margin" => { acc with margin = v' v }
#             | "marginBottom" => { acc with marginBottom = v' v }
#             | "maxHeight" => { acc with maxHeight = v' v }
#             | "onChange" => { acc with onChange = v' v }
#             | "onClick" => { acc with onClick = v' v }
#             | "outline" => { acc with outline = v' v }
#             | "overflowY" => { acc with overflowY = v' v }
#             | "padding" => { acc with padding = v' v }
#             | "paddingTop" => { acc with paddingTop = v' v }
#             | "position" => { acc with position = v' v }
#             | "right" => { acc with right = v' v }
#             | "size" => { acc with size = v' v }
#             | "spacing" => { acc with spacing = v' v }
#             | "status" => { acc with status = v' v }
#             | "striped" => { acc with striped = v' v }
#             | "thickness" => { acc with thickness = v' v }
#             | "title" => { acc with title = v' v }
#             | "top" => { acc with top = v' v }
#             | "width" => { acc with width = v' v }
#             | "zIndex" => { acc with zIndex = v' v }
#             | _ => failwith $"$\"unknown prop: {!k} = {!v}\""
#         ) empty_props'
#     |> new_props
#
#
# let props_array props =
#     inl props = match props with props_heap x => x
#
#     a ;[
#         jsx_prop "aria-label" props.ariaLabel
#         jsx_prop "as" props.as'
#         jsx_prop "backgroundColor" props.backgroundColor
#         jsx_prop "border" props.border
#         jsx_prop "bottom" props.bottom
#         jsx_prop "color" props.color
#         jsx_prop "checked" props.checked
#         jsx_prop "children" props.children
#         jsx_prop "colorScheme" props.colorScheme
#         jsx_prop "compact" props.compact
#         jsx_prop "display" props.display
#         jsx_prop "direction" props.direction
#         jsx_prop "external" props.external
#         jsx_prop "flex" props.flex
#         jsx_prop "flexDirection" props.flexDirection
#         jsx_prop "fontSize" props.fontSize
#         jsx_prop "height" props.height
#         jsx_prop "href" props.href
#         jsx_prop "icon" props.icon
#         jsx_prop "id" props.id
#         jsx_prop "justifyContent" props.justifyContent
#         jsx_prop "left" props.left
#         jsx_prop "leftIcon" props.leftIcon
#         jsx_prop "lineHeight" props.lineHeight
#         jsx_prop "margin" props.margin
#         jsx_prop "marginBottom" props.marginBottom
#         jsx_prop "maxHeight" props.maxHeight
#         jsx_prop "onChange" props.onChange
#         jsx_prop "onClick" props.onClick
#         jsx_prop "outline" props.outline
#         jsx_prop "overflowY" props.overflowY
#         jsx_prop "padding" props.padding
#         jsx_prop "paddingTop" props.paddingTop
#         jsx_prop "position" props.position
#         jsx_prop "right" props.right
#         jsx_prop "size" props.size
#         jsx_prop "spacing" props.spacing
#         jsx_prop "status" props.status
#         jsx_prop "striped" props.striped
#         jsx_prop "thickness" props.thickness
#         jsx_prop "title" props.title
#         jsx_prop "top" props.top
#         jsx_prop "width" props.width
#         jsx_prop "zIndex" props.zIndex
#     ]
#     |> am.filter (function Some v => true | None => false) |> am.map optionm.value
#
#
# inl create_component_ext name module props : element_ =
#     inl name : string = name
#     inl module : string = module
#     inl props : a i32 prop_ = props
#     inl props = create_obj props
#     inl createComponent' = createComponent_ ()
#     inl result : element_ = $"!createComponent'.Invoke ((import !name !module), !props) |> unbox<JSX.Element>"
#     result
#
# inl anchor props = create_component_ext "Anchor" "@hope-ui/solid" (props_array props)
# inl box props = create_component_ext "Box" "@hope-ui/solid" (props_array props)
# inl button props = create_component_ext "Button" "@hope-ui/solid" (props_array props)
# inl icon_button props = create_component_ext "IconButton" "@hope-ui/solid" (props_array props)
# inl checkbox props = create_component_ext "Checkbox" "@hope-ui/solid" (props_array props)
# inl icon props = create_component_ext "Icon" "@hope-ui/solid" (props_array props)
# inl stack props = create_component_ext "Stack" "@hope-ui/solid" (props_array props)
# inl table props = create_component_ext "Table" "@hope-ui/solid" (props_array props)
# inl tbody props = create_component_ext "Tbody" "@hope-ui/solid" (props_array props)
# inl td props = create_component_ext "Td" "@hope-ui/solid" (props_array props)
# inl tr props = create_component_ext "Tr" "@hope-ui/solid" (props_array props)
#
#
# let use_store forall a {record}. () =
#     inl useStoreon' = useStoreon_ ()
#     inl fns : array js_function_ = $"!useStoreon'.Invoke () |> unbox<JS.Function[]>"
#     inl state : mut a = $"!fns.[0] |> unbox"
#     inl dispatch_raw : js_function_ = $"!fns.[1] |> unbox"
#     inl dispatch new_state : () =
#         inl new_state : mut a = new_state
#         $"!dispatch_raw.Invoke (\"set\", !new_state) |> unbox"
#     state, dispatch
#
# inl els items =
#     inl items : array element_ = items
#     inl result : element_ = $"!items |> unbox<JSX.Element>"
#     result
#
# inl js_object_entries obj = $"emitJsExpr !obj \"Object.entries($0)\""
#
# let create_component cmp props =
#     inl cmp : js_function_ = $"!cmp |> unbox<JS.Function>"
#     inl props : props_heap = props
#     inl createComponent' = createComponent_ ()
#     inl result : element_ = $"!createComponent'.Invoke (!cmp, !props) |> unbox<JSX.Element>"
#     result
#
# inl create_effect on =
#     inl create_effect' = createEffect_ ()
#     $"!create_effect'.Invoke !on |> ignore" : ()
#
# let create_signal forall a. default_value =
#     inl createSignal' = createSignal_ ()
#     inl fns : array js_function_ = $"!createSignal'.Invoke !default_value |> unbox<JS.Function[]>"
#     inl get = $"!fns.[0] |> unbox" : () -> a
#     inl set = $"!fns.[1] |> unbox" : a -> ()
#     get, set
#
# inl on deps fn =
#     inl on' = on_ ()
#     $"!on'.Invoke (!deps, !fn) |> unbox<JS.Function>" : js_function_
#
# inl empty_fragment () =
#     $"Html.fragment []" : element_
#
# let merge_props old new =
#     inl old : heap props__ = old
#     inl new : props__ = new
#     inl new = heap new
#
#     inl merge_prop old new =
#         match old, new with
#         | _, Some new => Some new
#         | Some old, _ => Some old
#         | _ => None
#
#     inl result : heap props__ = heap {
#         ariaLabel = merge_prop old.ariaLabel new.ariaLabel
#         as' = merge_prop old.as' new.as'
#         backgroundColor = merge_prop old.backgroundColor new.backgroundColor
#         border = merge_prop old.border new.border
#         bottom = merge_prop old.bottom new.bottom
#         color = merge_prop old.color new.color
#         checked = merge_prop old.checked new.checked
#         children = merge_prop old.children new.children
#         colorScheme = merge_prop old.colorScheme new.colorScheme
#         compact = merge_prop old.compact new.compact
#         direction = merge_prop old.direction new.direction
#         display = merge_prop old.display new.display
#         external = merge_prop old.external new.external
#         flex = merge_prop old.flex new.flex
#         flexDirection = merge_prop old.flexDirection new.flexDirection
#         fontSize = merge_prop old.fontSize new.fontSize
#         height = merge_prop old.height new.height
#         href = merge_prop old.href new.href
#         icon = merge_prop old.icon new.icon
#         id = merge_prop old.id new.id
#         status = merge_prop old.status new.status
#         justifyContent = merge_prop old.justifyContent new.justifyContent
#         left = merge_prop old.left new.left
#         leftIcon = merge_prop old.leftIcon new.leftIcon
#         lineHeight = merge_prop old.lineHeight new.lineHeight
#         margin = merge_prop old.margin new.margin
#         marginBottom = merge_prop old.marginBottom new.marginBottom
#         maxHeight = merge_prop old.maxHeight new.maxHeight
#         onChange = merge_prop old.onChange new.onChange
#         onClick = merge_prop old.onClick new.onClick
#         outline = merge_prop old.outline new.outline
#         overflowY = merge_prop old.overflowY new.overflowY
#         padding = merge_prop old.padding new.padding
#         paddingTop = merge_prop old.paddingTop new.paddingTop
#         position = merge_prop old.position new.position
#         right = merge_prop old.right new.right
#         size = merge_prop old.size new.size
#         spacing = merge_prop old.spacing new.spacing
#         striped = merge_prop old.striped new.striped
#         thickness = merge_prop old.thickness new.thickness
#         title = merge_prop old.title new.title
#         top = merge_prop old.top new.top
#         width = merge_prop old.width new.width
#         zIndex = merge_prop old.zIndex new.zIndex
#     }
#
#     props_heap result
#
# inl external_link props =
#     inl props = match props with props_heap x => x
#     inl empty_props' = empty_props ()
#
#     anchor
#         ({ empty_props' with
#             external = Some true
#             children = Some (fun () => els ;[
#                 str (props.href |> optionm.defaultWith "")
#                 str "&nbsp;"
#                 icon (new_props { empty_props' with as' = Some (biRegularLinkExternal_ ()) })
#             ])
#         } |> merge_props props)
#
# inl base_button props =
#     inl props = match props with props_heap x => x
#     inl empty_props' = empty_props ()
#
#     button
#         ({ empty_props' with
#             size = Some "xs"
#             justifyContent = Some "left"
#             compact = Some true
#             colorScheme = Some "neutral"
#         } |> merge_props props)
#
# inl base_table props =
#     inl props = match props with props_heap x => x
#     inl empty_props' = empty_props ()
#
#     create_component
#         table
#         (new_props { empty_props' with
#             display = Some "flex"
#             flex = Some 1
#             flexDirection = Some "column"
#             striped = Some "odd"
#             children = Some (fun () => els ;[
#                 create_component
#                     tbody
#                     (new_props { empty_props' with
#                         display = Some "flex"
#                         flexDirection = Some "column"
#                         children = props.children
#                     })
#             ])
#         })
#
#
#
#
#
# type state__ =
#     {
#         ui : {
#             modal : i32
#         }
#     }
#
#
# inl loader {props loaded' modal on_load} =
#     inl props = match props with props_heap x => x
#     inl empty_props' = empty_props ()
#
#     inl (state : mut state__), dispatch = use_store ()
#
#     inl loader_id : i32 = $"Random().Next()"
#
#     inl loaded, set_loaded = create_signal (loaded' : bool)
#     inl refreshing, set_refreshing = create_signal false
#     inl modal, set_modal = create_signal (modal : bool)
#
#     create_effect
#         (on
#             (fun () => ;[refreshing ()])
#             (fun () => if refreshing () then set_refreshing false)
#         )
#
#     inl on_load' () =
#         match on_load with
#         | Some on_load => on_load state dispatch
#         | None => ()
#
#     if loaded' then on_load' ()
#
#     inl icon_height = "20px"
#     inl button_size = "14px"
#
#     create_component
#         box
#         (new_props { empty_props' with
#             id = props.id
#             display = Some "flex"
#             flex = Some 1
#             children = Some (fun () => els ;[
#                 if loaded () |> not then
#                     create_component
#                         box
#                         (new_props { empty_props' with
#                             children = Some (fun () => els ;[
#                                 create_component
#                                     base_button
#                                     (new_props { empty_props' with
#                                         onClick = Some (fun () =>
#                                             on_load' ()
#                                             set_loaded true
#                                         )
#                                         children = Some (fun () => els ;[
#                                             str "Load"
#                                         ])
#                                     })
#                             ]
#                         )})
#                 else
#                     create_component
#                         box
#                         (new_props { empty_props' with
#                             display = Some "flex"
#                             flex = Some 1
#                             zIndex = if modal () then Some 1 else None
#                             position = if modal () then Some "absolute" else None
#                             top = if modal () then Some "0" else None
#                             right = if modal () then Some "0" else None
#                             bottom = if modal () then Some "0" else None
#                             left = if modal () then Some "0" else None
#                             backgroundColor = if modal () then Some "$bg" else None
#                             children = Some (fun () => els ;[
#                                 match props.children with
#                                 | Some children =>
#                                     create_component
#                                         box
#                                         (new_props { empty_props' with
#                                             flex = Some 1
#                                             display = Some "flex"
#                                             position = if state.ui.modal <= 0 then Some "relative" else None
#                                             children = Some (fun () => els ;[
#                                                 create_component
#                                                     stack
#                                                     (new_props { empty_props' with
#                                                         display = if state.ui.modal = loader_id then Some "none" else None
#                                                         direction = Some "row"
#                                                         spacing = Some "3px"
#                                                         position = Some "absolute"
#                                                         top = Some "6px"
#                                                         right = Some "6px"
#                                                         zIndex = Some 1
#                                                         children = Some (fun () => els ;[
#                                                             icon_button
#                                                                 (new_props { empty_props' with
#                                                                     ariaLabel = Some "Refresh"
#                                                                     size = Some "xs"
#                                                                     height = Some icon_height
#                                                                     colorScheme = Some "neutral"
#                                                                     onClick = Some (fun () => set_refreshing true)
#                                                                     icon = Some (
#                                                                         create_component
#                                                                             (biRegularRefresh_ ())
#                                                                             (new_props { empty_props' with
#                                                                                 size = Some button_size
#                                                                             })
#                                                                     )
#                                                                 })
#                                                             icon_button
#                                                                 (new_props { empty_props' with
#                                                                     ariaLabel = Some (if modal () then "Restore" else "Maximize")
#                                                                     size = Some "xs"
#                                                                     height = Some icon_height
#                                                                     colorScheme = Some "neutral"
#                                                                     onClick = Some (fun () =>
#                                                                         inl new_modal = not (modal ())
#                                                                         set_modal new_modal
#                                                                         inl new_state = state
#                                                                         new_state.ui.modal <- if new_modal then loader_id else 0
#                                                                         inspect ("new_state")
#                                                                         dispatch new_state
#                                                                     )
#                                                                     icon = Some (
#                                                                         create_component
#                                                                             if modal ()
#                                                                             then biRegularDownArrow_ ()
#                                                                             else biRegularUpArrow_ ()
#                                                                             (new_props { empty_props' with
#                                                                                 size = Some button_size
#                                                                             })
#                                                                     )
#                                                                 })
#                                                             icon_button
#                                                                 (new_props { empty_props' with
#                                                                     ariaLabel = Some "Unload"
#                                                                     size = Some "xs"
#                                                                     height = Some icon_height
#                                                                     colorScheme = Some "neutral"
#                                                                     onClick = Some (fun () => set_loaded false)
#                                                                     icon = Some (
#                                                                         create_component
#                                                                             (biRegularUndo_ ())
#                                                                             (new_props { empty_props' with
#                                                                                 size = Some button_size
#                                                                             })
#                                                                     )
#                                                                 })
#                                                         ])
#                                                     })
#
#                                                 if not (refreshing ()) then
#                                                     children ()
#                                                 else
#                                                     empty_fragment ()
#                                             ])
#                                         })
#                                 | None =>
#                                     empty_fragment ()
#                             ])
#                         })
#             ])
#         })
#
# inl row {props on_load} =
#     inl props = match props with props_heap x => x
#     inl empty_props' = empty_props ()
#
#     inl checked, set_checked = create_signal (props.status <> Some false)
#
#     create_component
#         tr
#         (new_props { empty_props' with
#             id = props.id
#             display = Some "flex"
#             flex = Some 1
#             border = Some "1px solid $neutral5"
#             flexDirection = Some $"{| ````@initial```` = \"column\"; ````@sm```` = \"row\" |} |> unbox<string>"
#             children = Some (fun () => els ;[
#                 match props.title with
#                 | Some title =>
#                     create_component
#                         td
#                         (new_props { empty_props' with
#                             border = Some "0 !important"
#                             color = Some "$neutral9"
#                             display = Some "flex"
#                             flexDirection = Some "column"
#                             fontSize = Some "$sm"
#                             outline = Some "1px solid $neutral5"
#                             padding = Some "3px 20px 0 8px"
#                             children = Some (fun () => els ;[
#                                 match props.status with
#                                 | Some status =>
#                                     checkbox
#                                         (new_props { empty_props' with
#                                             size = Some "sm"
#                                             marginBottom = Some "2px"
#                                             checked = Some (checked ())
#                                             colorScheme = Some "neutral"
#                                             onChange = Some (fun e => set_checked $"!e?target?checked")
#                                             children = Some (fun () => els ;[
#                                                 box
#                                                     (new_props { empty_props' with
#                                                         paddingTop = Some "2px"
#                                                         children = Some (fun () => els ;[
#                                                             title
#                                                         ])
#                                                     })
#                                             ])
#                                         })
#                                 | None =>
#                                     title
#                             ])
#                         })
#                 | None =>
#                     empty_fragment ()
#
#                 match props.children with
#                 | Some children =>
#                     create_component
#                         td
#                         (new_props { empty_props' with
#                             border = Some "0 !important"
#                             outline = Some "0"
#                             margin = Some "0"
#                             padding = props.padding |> optionm.defaultWith "0" |> Some
#                             display = Some "flex"
#                             flex = Some 6
#                             flexDirection = Some "column"
#                             fontSize = Some "$sm"
#                             maxHeight = Some "85vh"
#                             overflowY = Some "auto"
#                             children = Some (fun () => els ;[
#                                 match props.status with
#                                 | Some status =>
#                                     if checked () then
#                                         loader
#                                             {
#                                                 loaded' = true
#                                                 modal = false
#                                                 on_load
#                                                 props = (new_props { empty_props' with
#                                                     children = Some (fun () => els ;[
#                                                         children ()
#                                                     ])
#                                                 })
#                                             }
#                                     else
#                                         empty_fragment ()
#                                 | None => children ()
#                             ])
#                         })
#                 | None =>
#                     create_component
#                         td
#                         (new_props { empty_props' with
#                             padding = Some "0"
#                             lineHeight = Some "9px"
#                             children = Some (fun () => els ;[
#                                 str "&nbsp;"
#                             ])
#                         })
#             ])
#         })
#
# inl links () =
#     inl empty_props' = empty_props ()
#
#     create_component
#         base_table
#         (new_props { empty_props' with
#             children = Some (fun () => els ;[
#                 row
#                     {
#                         on_load = None
#                         props = (new_props { empty_props' with
#                             padding = Some "1px 6px"
#                             children = Some (fun () => els ;[
#                                 create_component
#                                     external_link
#                                     (new_props { empty_props' with
#                                         href = Some "https://github.com/fc1943s/tictactoe_spiral"
#                                     })
#                             ])
#                         })
#                     }
#                 row
#                     {
#                         on_load = None
#                         props = (new_props { empty_props' with
#                             padding = Some "1px 6px"
#                             children = Some (fun () => els ;[
#                                 create_component
#                                     external_link
#                                     (new_props { empty_props' with
#                                         href = Some "https://fc1943s.github.io/tictactoe_spiral"
#                                     })
#                             ])
#                         })
#                     }
#                 row
#                     {
#                         on_load = None
#                         props = (new_props { empty_props' with
#                             padding = Some "1px 6px"
#                             children = Some (fun () => els ;[
#                                 create_component
#                                     external_link
#                                     (new_props { empty_props' with
#                                         href = Some "https://fc1943s.github.io/tictactoe_spiral/docs"
#                                     })
#                             ])
#                         })
#                     }
#             ])
#         })
#
# inl main () =
#     imports ()
#     tests ()
#
#     a ;[
#         new_jsx_prop "base_button" base_button
#         new_jsx_prop "base_table" base_table
#         new_jsx_prop "create_obj_props" create_obj_props
#         new_jsx_prop "external_link" external_link
#         new_jsx_prop "links" links
#         new_jsx_prop "loader" loader
#         new_jsx_prop "row" row
#     ]
#     |> create_obj |> dyn |> ignore
# Out:
# <magic:f104f986d9b342ee817410081adaa567>
# {'run_node_output': [], 'fsx_path': '/workspaces/spiral-notebook/lib_fsx/components_spi.fsx', 'len(new_code_fsx)': 158611, 'new_code_fsx[:100]': '#r "nuget: Feliz.JSX.Solid, 1.0.0-beta-001"\nopen System\nopen Fable.Core\nopen Fable.Core.JsInterop\nop'}
# '/workspaces/spiral-notebook/main.spi'

# %%
# !dotnet fable ../lib_fsx --optimize --lang typescript --typedArrays false --extension .tsx -o ../lib_ts
# Out:
# ==Fable: F# to TypeScript compiler 4.0.0-theta-003
# Thanks to the contributor! @selketjah
# Stand with Ukraine! https://standwithukraine.com.ua/
#
# Parsing ../lib_fsx/tictactoe_spiral.fsproj...
# Retrieving project options from cache, in case of issues run `dotnet fable clean` or try `--noCache` option.
# Project and references (8 source files) parsed in 127ms
#
# Started Fable compilation...
# ...

# %%
# !dotnet build ../lib_fsx
